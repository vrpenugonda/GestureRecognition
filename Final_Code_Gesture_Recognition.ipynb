# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started. Once you have completed the code you can download the notebook for making a submission.

# %%
import numpy as np
import os
from imageio import imread
from skimage.transform import resize
import datetime
import os

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from tensorflow import keras
import tensorflow as tf
tf.random.set_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %% [markdown]
# **data path: /home/datasets/Project_data**

# %%
train_doc = np.random.permutation(open('/home/datasets/Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('/home/datasets/Project_data/val.csv').readlines())
batch_size = 30 #experiment with the batch size

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
imageX_dim = 100
imageY_dim = 100

# %%
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = list(range(0, 30, 3)) #create a list of image numbers you want to use for a particular video
    num, x, y = len(img_idx), imageX_dim, imageY_dim
    while True:
        t = np.random.permutation(folder_list)
        total_folders = len(folder_list)
        num_batches = total_folders // batch_size #calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            # 'num' is the number of images you use for each video, (x,y) is the final size of the input images and 3 is the number of channels RGB
            batch_data = np.zeros((batch_size,num,x,y,3)) 
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    resizedImage = resize(image, (x, y),anti_aliasing=True)
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    batch_data[folder,idx,:,:,0] = resizedImage[:, :, 0] / 255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = resizedImage[:, :, 1] / 255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = resizedImage[:, :, 2] / 255 #normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do
            
            
        missing_count = total_folders - (num_batches * batch_size)
        for folder in range(missing_count):
            imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
            for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                resizedImage = resize(image, (x, y),anti_aliasing=True)
                
                batch_data[folder,idx,:,:,0] = resizedImage[:, :, 0] / 255 #normalise and feed in the image
                batch_data[folder,idx,:,:,1] = resizedImage[:, :, 1] / 255 #normalise and feed in the image
                batch_data[folder,idx,:,:,2] = resizedImage[:, :, 2] / 255 #normalise and feed in the image

            batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
        yield batch_data, batch_labels
        # write the code for the remaining data points which are left after full batches

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = '/home/datasets/Project_data/train'
val_path = '/home/datasets/Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 30
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 30

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Dropout, Flatten, BatchNormalization, Activation,Conv2D, Conv3D, MaxPooling3D, TimeDistributed, MaxPooling3D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import optimizers, regularizers
from tensorflow.keras.regularizers import l2

def Conv2DWGRU(batch_size):
        Conv2DWGRU_Model = Sequential()
        
        Conv2DWGRU_Model.add(TimeDistributed(Conv2D(32, (1, 1), padding='same'), input_shape=(10, imageX_dim, imageY_dim, 3)))
        Conv2DWGRU_Model.add(TimeDistributed(Activation('relu')))
        Conv2DWGRU_Model.add(TimeDistributed(MaxPooling2D((3, 3), strides = (2,2))))
        Conv2DWGRU_Model.add(TimeDistributed(BatchNormalization()))
        
        Conv2DWGRU_Model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same')))
        Conv2DWGRU_Model.add(TimeDistributed(Activation('relu')))
        Conv2DWGRU_Model.add(TimeDistributed(MaxPooling2D((3, 3), strides = (2,2))))
        Conv2DWGRU_Model.add(TimeDistributed(BatchNormalization()))
        
        Conv2DWGRU_Model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01))))
        Conv2DWGRU_Model.add(TimeDistributed(Activation('relu')))
        Conv2DWGRU_Model.add(TimeDistributed(BatchNormalization()))
        Conv2DWGRU_Model.add(Dropout(0.25))
        
        Conv2DWGRU_Model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01))))
        Conv2DWGRU_Model.add(TimeDistributed(Activation('relu')))
        Conv2DWGRU_Model.add(TimeDistributed(MaxPooling2D((3, 3))))
        
        Conv2DWGRU_Model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same')))
        Conv2DWGRU_Model.add(TimeDistributed(Activation('relu')))        
        Conv2DWGRU_Model.add(Dropout(0.25))
        
        Conv2DWGRU_Model.add(TimeDistributed(Conv2D(128, (3, 3), padding='same', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01))))
        Conv2DWGRU_Model.add(TimeDistributed(Activation('relu')))
        Conv2DWGRU_Model.add(Dropout(0.50))
        
        Conv2DWGRU_Model.add(TimeDistributed(Conv2D(256, (5, 5), padding='same', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01))))
        Conv2DWGRU_Model.add(TimeDistributed(Activation('relu')))
        
        Conv2DWGRU_Model.add(TimeDistributed(Flatten()))
                
        Conv2DWGRU_Model.add(Dense(16))
        Conv2DWGRU_Model.add(Dropout(.50))
        
        #GRU
        Conv2DWGRU_Model.add(GRU(64, return_sequences=False))        
        
        Conv2DWGRU_Model.add(Dense(5, activation='softmax'))
        
        return Conv2DWGRU_Model

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
rnnGRUModel = Conv2DWGRU(batch_size)
optimiser = optimizers.Adam() #write your optimizer
rnnGRUModel.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (rnnGRUModel.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_63 (TimeDis (None, 10, 100, 100, 32)  128
# _________________________________________________________________
# time_distributed_64 (TimeDis (None, 10, 100, 100, 32)  0
# _________________________________________________________________
# time_distributed_65 (TimeDis (None, 10, 49, 49, 32)    0
# _________________________________________________________________
# time_distributed_66 (TimeDis (None, 10, 49, 49, 32)    128
# _________________________________________________________________
# time_distributed_67 (TimeDis (None, 10, 49, 49, 32)    9248
# _________________________________________________________________
# time_distributed_68 (TimeDis (None, 10, 49, 49, 32)    0
# _________________________________________________________________
# time_distributed_69 (TimeDis (None, 10, 24, 24, 32)    0
# _________________________________________________________________
# time_distributed_70 (TimeDis (None, 10, 24, 24, 32)    128
# _________________________________________________________________
# time_distributed_71 (TimeDis (None, 10, 24, 24, 64)    18496
# _________________________________________________________________
# time_distributed_72 (TimeDis (None, 10, 24, 24, 64)    0
# _________________________________________________________________
# time_distributed_73 (TimeDis (None, 10, 24, 24, 64)    256
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 10, 24, 24, 64)    0
# _________________________________________________________________
# time_distributed_74 (TimeDis (None, 10, 24, 24, 64)    36928
# _________________________________________________________________
# time_distributed_75 (TimeDis (None, 10, 24, 24, 64)    0
# _________________________________________________________________
# time_distributed_76 (TimeDis (None, 10, 8, 8, 64)      0
# _________________________________________________________________
# time_distributed_77 (TimeDis (None, 10, 8, 8, 64)      36928
# _________________________________________________________________
# time_distributed_78 (TimeDis (None, 10, 8, 8, 64)      0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 10, 8, 8, 64)      0
# _________________________________________________________________
# time_distributed_79 (TimeDis (None, 10, 8, 8, 128)     73856
# _________________________________________________________________
# time_distributed_80 (TimeDis (None, 10, 8, 8, 128)     0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 10, 8, 8, 128)     0
# _________________________________________________________________
# time_distributed_81 (TimeDis (None, 10, 8, 8, 256)     819456
# _________________________________________________________________
# time_distributed_82 (TimeDis (None, 10, 8, 8, 256)     0
# _________________________________________________________________
# time_distributed_83 (TimeDis (None, 10, 16384)         0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10, 16)            262160
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 10, 16)            0
# _________________________________________________________________
# gru_3 (GRU)                  (None, 64)                15744
# _________________________________________________________________
# dense_7 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 1,273,781
# Trainable params: 1,273,525
# Non-trainable params: 256
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

#print(next(train_generator))

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
#filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:01.5f}-{val_categorical_accuracy:.5f}.h5'
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}.h5'

reduceLRConv2DGRU = ReduceLROnPlateau(monitor = "val_loss", factor = 0.1, patience = 2,verbose = 1, mode = "auto", cooldown = 0)
checkpointConv2DGRU = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', save_freq = num_epochs)
#LR = DecayLR(base_lr=0.1) # write the REducelronplateau code here
callbacks_list = [checkpointConv2DGRU, reduceLRConv2DGRU]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit` method to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
rnnGRUModel_hist = rnnGRUModel.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, callbacks=callbacks_list, validation_data=val_generator, 
                                   validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
#callbacks=callbacks_list,
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 30
# Epoch 1/30
# 23/23 [==============================] - ETA: 0s - loss: 4.5774 - categorical_accuracy: 0.2101Source path =  /home/datasets/Project_data/val ; batch size = 30
# 23/23 [==============================] - 37s 2s/step - loss: 4.5774 - categorical_accuracy: 0.2101 - val_loss: 3.5174 - val_categorical_accuracy: 0.2333
# Epoch 2/30
#  6/23 [======>.......................] - ETA: 19s - loss: 3.4026 - categorical_accuracy: 0.2222
# Epoch 00002: saving model to model_init_2021-06-2717_41_13.168834/model-00002-3.36826-0.22381.h5
# 23/23 [==============================] - 37s 2s/step - loss: 2.9490 - categorical_accuracy: 0.2609 - val_loss: 2.4880 - val_categorical_accuracy: 0.2917
# Epoch 3/30
# 13/23 [===============>..............] - ETA: 12s - loss: 2.2217 - categorical_accuracy: 0.3308
# Epoch 00003: saving model to model_init_2021-06-2717_41_13.168834/model-00003-2.21218-0.32143.h5
# 23/23 [==============================] - 37s 2s/step - loss: 2.0792 - categorical_accuracy: 0.3638 - val_loss: 2.0899 - val_categorical_accuracy: 0.1667
# Epoch 4/30
# 20/23 [=========================>....] - ETA: 4s - loss: 1.6401 - categorical_accuracy: 0.4767
# Epoch 00004: saving model to model_init_2021-06-2717_41_13.168834/model-00004-1.62878-0.48095.h5
# 23/23 [==============================] - 36s 2s/step - loss: 1.6073 - categorical_accuracy: 0.4899 - val_loss: 1.9060 - val_categorical_accuracy: 0.2500
# Epoch 5/30
# 23/23 [==============================] - 37s 2s/step - loss: 1.3791 - categorical_accuracy: 0.5348 - val_loss: 1.8401 - val_categorical_accuracy: 0.2083
# Epoch 6/30
#  4/23 [====>.........................] - ETA: 17s - loss: 1.6154 - categorical_accuracy: 0.5000
# Epoch 00006: saving model to model_init_2021-06-2717_41_13.168834/model-00006-1.54809-0.52000.h5
# 23/23 [==============================] - 37s 2s/step - loss: 1.3413 - categorical_accuracy: 0.5710 - val_loss: 1.8341 - val_categorical_accuracy: 0.2333
# Epoch 7/30
# 11/23 [=============>................] - ETA: 15s - loss: 1.1087 - categorical_accuracy: 0.6697
# Epoch 00007: saving model to model_init_2021-06-2717_41_13.168834/model-00007-1.13030-0.66389.h5
# 23/23 [==============================] - 38s 2s/step - loss: 1.0735 - categorical_accuracy: 0.6783 - val_loss: 1.7667 - val_categorical_accuracy: 0.3333
# Epoch 8/30
# 18/23 [======================>.......] - ETA: 6s - loss: 0.9041 - categorical_accuracy: 0.7370
# Epoch 00008: saving model to model_init_2021-06-2717_41_13.168834/model-00008-0.91736-0.72982.h5
# 23/23 [==============================] - 36s 2s/step - loss: 0.9181 - categorical_accuracy: 0.7304 - val_loss: 1.7366 - val_categorical_accuracy: 0.2333
# Epoch 9/30
# 23/23 [==============================] - 37s 2s/step - loss: 0.7879 - categorical_accuracy: 0.7768 - val_loss: 1.6919 - val_categorical_accuracy: 0.3333
# Epoch 10/30
#  2/23 [=>............................] - ETA: 19s - loss: 0.8712 - categorical_accuracy: 0.7167
# Epoch 00010: saving model to model_init_2021-06-2717_41_13.168834/model-00010-0.84840-0.74444.h5
# 23/23 [==============================] - 37s 2s/step - loss: 0.8110 - categorical_accuracy: 0.7594 - val_loss: 2.2314 - val_categorical_accuracy: 0.2167
# Epoch 11/30
#  9/23 [==========>...................] - ETA: 17s - loss: 0.7470 - categorical_accuracy: 0.8037
# Epoch 00011: saving model to model_init_2021-06-2717_41_13.168834/model-00011-0.76535-0.78667.h5
# 23/23 [==============================] - 37s 2s/step - loss: 0.7389 - categorical_accuracy: 0.7942 - val_loss: 1.5858 - val_categorical_accuracy: 0.4083
# Epoch 12/30
# 16/23 [===================>..........] - ETA: 9s - loss: 0.6269 - categorical_accuracy: 0.8333
# Epoch 00012: saving model to model_init_2021-06-2717_41_13.168834/model-00012-0.61697-0.83725.h5
# 23/23 [==============================] - 36s 2s/step - loss: 0.6162 - categorical_accuracy: 0.8348 - val_loss: 1.7093 - val_categorical_accuracy: 0.3667
# Epoch 13/30
# 23/23 [==============================] - 36s 2s/step - loss: 0.5365 - categorical_accuracy: 0.8536 - val_loss: 1.4708 - val_categorical_accuracy: 0.4917
# Epoch 14/30
#
# Epoch 00014: saving model to model_init_2021-06-2717_41_13.168834/model-00014-0.39872-0.93333.h5
# 23/23 [==============================] - 38s 2s/step - loss: 0.5785 - categorical_accuracy: 0.8464 - val_loss: 1.5911 - val_categorical_accuracy: 0.4500
# Epoch 15/30
#  7/23 [========>.....................] - ETA: 20s - loss: 0.5399 - categorical_accuracy: 0.8667
# Epoch 00015: saving model to model_init_2021-06-2717_41_13.168834/model-00015-0.53214-0.85833.h5
# 23/23 [==============================] - ETA: 0s - loss: 0.4799 - categorical_accuracy: 0.8725
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 23/23 [==============================] - 39s 2s/step - loss: 0.4799 - categorical_accuracy: 0.8725 - val_loss: 1.5267 - val_categorical_accuracy: 0.4000
# Epoch 16/30
# 14/23 [=================>............] - ETA: 11s - loss: 0.3737 - categorical_accuracy: 0.9310
# Epoch 00016: saving model to model_init_2021-06-2717_41_13.168834/model-00016-0.37985-0.92889.h5
# 23/23 [==============================] - 36s 2s/step - loss: 0.3976 - categorical_accuracy: 0.9130 - val_loss: 1.5329 - val_categorical_accuracy: 0.4750
# Epoch 17/30
# 21/23 [==========================>...] - ETA: 2s - loss: 0.3576 - categorical_accuracy: 0.9270
# Epoch 00017: saving model to model_init_2021-06-2717_41_13.168834/model-00017-0.35713-0.92879.h5
# 23/23 [==============================] - 38s 2s/step - loss: 0.3566 - categorical_accuracy: 0.9290 - val_loss: 1.3290 - val_categorical_accuracy: 0.6000
# Epoch 18/30
# 23/23 [==============================] - 38s 2s/step - loss: 0.3519 - categorical_accuracy: 0.9290 - val_loss: 1.1358 - val_categorical_accuracy: 0.6167
# Epoch 19/30
#  5/23 [=====>........................] - ETA: 20s - loss: 0.3353 - categorical_accuracy: 0.9267
# Epoch 00019: saving model to model_init_2021-06-2717_41_13.168834/model-00019-0.32981-0.92778.h5
# 23/23 [==============================] - 39s 2s/step - loss: 0.3266 - categorical_accuracy: 0.9362 - val_loss: 1.2309 - val_categorical_accuracy: 0.6417
# Epoch 20/30
# 12/23 [==============>...............] - ETA: 14s - loss: 0.3182 - categorical_accuracy: 0.9278
# Epoch 00020: saving model to model_init_2021-06-2717_41_13.168834/model-00020-0.31939-0.92821.h5
# 23/23 [==============================] - ETA: 0s - loss: 0.3161 - categorical_accuracy: 0.9319
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 23/23 [==============================] - 37s 2s/step - loss: 0.3161 - categorical_accuracy: 0.9319 - val_loss: 1.1976 - val_categorical_accuracy: 0.6417
# Epoch 21/30
# 19/23 [=======================>......] - ETA: 5s - loss: 0.2912 - categorical_accuracy: 0.9526
# Epoch 00021: saving model to model_init_2021-06-2717_41_13.168834/model-00021-0.29275-0.95167.h5
# 23/23 [==============================] - 38s 2s/step - loss: 0.2941 - categorical_accuracy: 0.9522 - val_loss: 1.1334 - val_categorical_accuracy: 0.6667
# Epoch 22/30
# 23/23 [==============================] - 37s 2s/step - loss: 0.2950 - categorical_accuracy: 0.9420 - val_loss: 0.9798 - val_categorical_accuracy: 0.6917
# Epoch 23/30
#  3/23 [==>...........................] - ETA: 20s - loss: 0.2754 - categorical_accuracy: 0.9556
# Epoch 00023: saving model to model_init_2021-06-2717_41_13.168834/model-00023-0.30863-0.95000.h5
# 23/23 [==============================] - 38s 2s/step - loss: 0.2926 - categorical_accuracy: 0.9507 - val_loss: 0.7962 - val_categorical_accuracy: 0.7750
# Epoch 24/30
# 10/23 [============>.................] - ETA: 17s - loss: 0.2949 - categorical_accuracy: 0.9333
# Epoch 00024: saving model to model_init_2021-06-2717_41_13.168834/model-00024-0.29306-0.93333.h5
# 23/23 [==============================] - 37s 2s/step - loss: 0.2931 - categorical_accuracy: 0.9420 - val_loss: 0.8671 - val_categorical_accuracy: 0.7250
# Epoch 25/30
# 17/23 [=====================>........] - ETA: 8s - loss: 0.2986 - categorical_accuracy: 0.9431
# Epoch 00025: saving model to model_init_2021-06-2717_41_13.168834/model-00025-0.29688-0.94444.h5
# 23/23 [==============================] - ETA: 0s - loss: 0.2938 - categorical_accuracy: 0.9478
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 23/23 [==============================] - 37s 2s/step - loss: 0.2938 - categorical_accuracy: 0.9478 - val_loss: 0.8482 - val_categorical_accuracy: 0.7000
# Epoch 26/30
# 23/23 [==============================] - 38s 2s/step - loss: 0.2919 - categorical_accuracy: 0.9478 - val_loss: 1.0521 - val_categorical_accuracy: 0.6500
# Epoch 27/30
#  1/23 [>.............................] - ETA: 0s - loss: 0.3756 - categorical_accuracy: 0.9000
# Epoch 00027: saving model to model_init_2021-06-2717_41_13.168834/model-00027-0.32565-0.93333.h5
# 23/23 [==============================] - 38s 2s/step - loss: 0.2897 - categorical_accuracy: 0.9565 - val_loss: 0.6428 - val_categorical_accuracy: 0.7583
# Epoch 28/30
#  8/23 [=========>....................] - ETA: 18s - loss: 0.3108 - categorical_accuracy: 0.9208
# Epoch 00028: saving model to model_init_2021-06-2717_41_13.168834/model-00028-0.29866-0.92963.h5
# 23/23 [==============================] - 37s 2s/step - loss: 0.2986 - categorical_accuracy: 0.9391 - val_loss: 0.7233 - val_categorical_accuracy: 0.7750
# Epoch 29/30
# 15/23 [==================>...........] - ETA: 10s - loss: 0.3028 - categorical_accuracy: 0.9444
# Epoch 00029: saving model to model_init_2021-06-2717_41_13.168834/model-00029-0.29706-0.94583.h5
# 23/23 [==============================] - ETA: 0s - loss: 0.2811 - categorical_accuracy: 0.9551
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 23/23 [==============================] - 37s 2s/step - loss: 0.2811 - categorical_accuracy: 0.9551 - val_loss: 0.6792 - val_categorical_accuracy: 0.8083
# Epoch 30/30
# 22/23 [===========================>..] - ETA: 1s - loss: 0.2914 - categorical_accuracy: 0.9485
# Epoch 00030: saving model to model_init_2021-06-2717_41_13.168834/model-00030-0.29265-0.94928.h5
# 23/23 [==============================] - 38s 2s/step - loss: 0.2926 - categorical_accuracy: 0.9493 - val_loss: 0.5686 - val_categorical_accuracy: 0.8583

# %%
import matplotlib.pyplot as plt

f, (ax1, ax2) = plt.subplots(1, 2, sharey=False)
f.set_figheight(5)
f.set_figwidth(15)

ax1.plot(rnnGRUModel_hist.history['val_categorical_accuracy'])
ax1.plot(rnnGRUModel_hist.history['categorical_accuracy'])
ax1.title.set_text('model accuracy')
ax1.set_ylabel('accuracy')
ax1.set_xlabel('epoch')
ax1.legend(['train', 'test'], loc='upper left')

ax2.plot(rnnGRUModel_hist.history['val_loss'])
ax2.plot(rnnGRUModel_hist.history['loss'])
ax2.title.set_text('Loss function')
ax2.set_ylabel('Loss')
ax2.set_xlabel('epoch')
ax2.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#Conv3D Model

from tensorflow.keras import regularizers

def Conv3DModel(batch_size):
        Conv3DModel = Sequential()
      
        Conv3DModel.add(Conv3D(8, kernel_size=(3, 3, 3),activation='relu', padding="same",input_shape=(10, 100, 100, 3)))
        Conv3DModel.add(MaxPooling3D(pool_size=(2, 2, 2)))
        Conv3DModel.add(BatchNormalization())
        
        Conv3DModel.add(Conv3D(16, kernel_size=(3, 3, 3),activation='relu', padding="same", kernel_regularizer=regularizers.l2(0.01), bias_regularizer=regularizers.l2(0.01)))
        Conv3DModel.add(MaxPooling3D(pool_size=(2, 2, 2)))
        Conv3DModel.add(BatchNormalization())
        #Conv3DModel.add(Dropout(0.2))
        
        Conv3DModel.add(Conv3D(32, kernel_size=(3, 3, 3),activation='relu', padding="same", kernel_regularizer=regularizers.l2(0.01), bias_regularizer=regularizers.l2(0.01)))
        Conv3DModel.add(MaxPooling3D(pool_size=(2, 2, 2)))
        Conv3DModel.add(BatchNormalization())
        #Conv3DModel.add(Dropout(0.2))
        
        Conv3DModel.add(Conv3D(32, kernel_size=(3, 3, 3),activation='relu', padding="same", kernel_regularizer=regularizers.l2(0.01), bias_regularizer=regularizers.l2(0.01)))
        Conv3DModel.add(MaxPooling3D(pool_size=(2, 2, 1),data_format='channels_first'))
        Conv3DModel.add(BatchNormalization())
        Conv3DModel.add(Dropout(0.1))
        
        Conv3DModel.add(Conv3D(64, kernel_size=(3, 3, 3),activation='relu', padding="same", kernel_regularizer=regularizers.l2(0.01), bias_regularizer=regularizers.l2(0.01)))        
        Conv3DModel.add(MaxPooling3D(pool_size=(2, 2, 1),data_format='channels_first'))
        Conv3DModel.add(BatchNormalization())
        Conv3DModel.add(Dropout(0.1))
        
        #Conv3DModel.add(Conv3D(128, kernel_size=(3, 3, 3),activation='relu', padding="same", kernel_regularizer=regularizers.l2(0.01), bias_regularizer=regularizers.l2(0.01)))
        #Conv3DModel.add(MaxPooling3D(pool_size=(2, 2, 2),data_format='channels_first'))
        #Conv3DModel.add(BatchNormalization())
        #Conv3DModel.add(Dropout(0.25))
        
        Conv3DModel.add(Flatten())
        
        Conv3DModel.add(Dense(128,activation='relu'))
        Conv3DModel.add(Dropout(0.1))
        
        Conv3DModel.add(Dense(64,activation='relu'))
        Conv3DModel.add(Dropout(0.1))
        
        Conv3DModel.add(Dense(32,activation='relu'))
        Conv3DModel.add(Dropout(0.1))
        
        Conv3DModel.add(Dense(5, activation='softmax'))
        
        return Conv3DModel

# %%
Conv3DModel = Conv3DModel(batch_size)
conv3d_optimiser = optimizers.Adam() #write your optimizer

Conv3DModel.compile(optimizer=conv3d_optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (Conv3DModel.summary())
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_21 (Conv3D)           (None, 10, 100, 100, 8)   656
# _________________________________________________________________
# max_pooling3d_21 (MaxPooling (None, 5, 50, 50, 8)      0
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 5, 50, 50, 8)      32
# _________________________________________________________________
# conv3d_22 (Conv3D)           (None, 5, 50, 50, 16)     3472
# _________________________________________________________________
# max_pooling3d_22 (MaxPooling (None, 2, 25, 25, 16)     0
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 2, 25, 25, 16)     64
# _________________________________________________________________
# conv3d_23 (Conv3D)           (None, 2, 25, 25, 32)     13856
# _________________________________________________________________
# max_pooling3d_23 (MaxPooling (None, 1, 12, 12, 32)     0
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 1, 12, 12, 32)     128
# _________________________________________________________________
# conv3d_24 (Conv3D)           (None, 1, 12, 12, 32)     27680
# _________________________________________________________________
# max_pooling3d_24 (MaxPooling (None, 1, 6, 6, 32)       0
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 1, 6, 6, 32)       128
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 1, 6, 6, 32)       0
# _________________________________________________________________
# conv3d_25 (Conv3D)           (None, 1, 6, 6, 64)       55360
# _________________________________________________________________
# max_pooling3d_25 (MaxPooling (None, 1, 3, 3, 64)       0
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 1, 3, 3, 64)       256
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 1, 3, 3, 64)       0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_24 (Dense)             (None, 128)               73856
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_26 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_27 (Dense)             (None, 5)                 165
# =================================================================
# Total params: 185,989
# Trainable params: 185,685
# Non-trainable params: 304
# _________________________________________________________________
# None

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
#filepath = model_name + 'model_3d-{epoch:05d}-{loss:.5f}-{val_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'
filepath = model_name + 'model_3d-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}.h5'
reduceLRConv3D = ReduceLROnPlateau(monitor = "val_loss", factor = 0.1, patience = 2,verbose = 1, mode = "auto", cooldown = 0)
checkpointConv3D = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', save_freq=num_epochs)

#LR = DecayLR(base_lr=0.1) # write the REducelronplateau code here
# callbacks_list = [checkpoint, LR]
# roc_callback = RocCallback()
callbacks_list = [reduceLRConv3D,checkpointConv3D]

# %%
conv3d_model_history = Conv3DModel.fit_generator(train_generator,  steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
                                           callbacks=callbacks_list,  validation_data=val_generator, validation_steps=validation_steps, class_weight=None,
                                           workers=1, initial_epoch=0)
# Out:
# Epoch 1/30
# 23/23 [==============================] - 36s 2s/step - loss: 2.1971 - categorical_accuracy: 0.4333 - val_loss: 2.2779 - val_categorical_accuracy: 0.2167
# Epoch 2/30
#  6/23 [======>.......................] - ETA: 20s - loss: 1.7636 - categorical_accuracy: 0.5722
# Epoch 00002: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00002-1.75922-0.57143.h5
# 23/23 [==============================] - 37s 2s/step - loss: 1.5791 - categorical_accuracy: 0.6232 - val_loss: 2.2073 - val_categorical_accuracy: 0.1833
# Epoch 3/30
# 13/23 [===============>..............] - ETA: 11s - loss: 1.3724 - categorical_accuracy: 0.6538
# Epoch 00003: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00003-1.36234-0.66429.h5
# 23/23 [==============================] - 37s 2s/step - loss: 1.2899 - categorical_accuracy: 0.7014 - val_loss: 2.2518 - val_categorical_accuracy: 0.2417
# Epoch 4/30
# 20/23 [=========================>....] - ETA: 3s - loss: 1.0966 - categorical_accuracy: 0.8150
# Epoch 00004: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00004-1.09588-0.81746.h5
# 23/23 [==============================] - ETA: 0s - loss: 1.0901 - categorical_accuracy: 0.8188
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 23/23 [==============================] - 37s 2s/step - loss: 1.0901 - categorical_accuracy: 0.8188 - val_loss: 2.2286 - val_categorical_accuracy: 0.2333
# Epoch 5/30
# 23/23 [==============================] - 35s 2s/step - loss: 0.9479 - categorical_accuracy: 0.8594 - val_loss: 2.2966 - val_categorical_accuracy: 0.2417
# Epoch 6/30
#  4/23 [====>.........................] - ETA: 20s - loss: 0.8944 - categorical_accuracy: 0.9000
# Epoch 00006: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00006-0.88341-0.90667.h5
# 23/23 [==============================] - ETA: 0s - loss: 0.8695 - categorical_accuracy: 0.8768
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 23/23 [==============================] - 35s 2s/step - loss: 0.8695 - categorical_accuracy: 0.8768 - val_loss: 2.2090 - val_categorical_accuracy: 0.2167
# Epoch 7/30
# 11/23 [=============>................] - ETA: 15s - loss: 0.8302 - categorical_accuracy: 0.9212
# Epoch 00007: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00007-0.82654-0.91944.h5
# 23/23 [==============================] - 39s 2s/step - loss: 0.8383 - categorical_accuracy: 0.9087 - val_loss: 2.2362 - val_categorical_accuracy: 0.2083
# Epoch 8/30
# 18/23 [======================>.......] - ETA: 5s - loss: 0.8315 - categorical_accuracy: 0.9111
# Epoch 00008: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00008-0.82582-0.91404.h5
# 23/23 [==============================] - ETA: 0s - loss: 0.8187 - categorical_accuracy: 0.9188
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 23/23 [==============================] - 36s 2s/step - loss: 0.8187 - categorical_accuracy: 0.9188 - val_loss: 2.2166 - val_categorical_accuracy: 0.1583
# Epoch 9/30
# 23/23 [==============================] - 36s 2s/step - loss: 0.8534 - categorical_accuracy: 0.9029 - val_loss: 2.1189 - val_categorical_accuracy: 0.2500
# Epoch 10/30
#  2/23 [=>............................] - ETA: 14s - loss: 0.9058 - categorical_accuracy: 0.8500
# Epoch 00010: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00010-0.85578-0.87778.h5
# 23/23 [==============================] - 36s 2s/step - loss: 0.8517 - categorical_accuracy: 0.9029 - val_loss: 2.0971 - val_categorical_accuracy: 0.3083
# Epoch 11/30
#  9/23 [==========>...................] - ETA: 18s - loss: 0.7839 - categorical_accuracy: 0.9296
# Epoch 00011: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00011-0.79914-0.91667.h5
# 23/23 [==============================] - 37s 2s/step - loss: 0.8216 - categorical_accuracy: 0.9072 - val_loss: 2.0460 - val_categorical_accuracy: 0.2917
# Epoch 12/30
# 16/23 [===================>..........] - ETA: 8s - loss: 0.8384 - categorical_accuracy: 0.9000
# Epoch 00012: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00012-0.83447-0.90196.h5
# 23/23 [==============================] - 37s 2s/step - loss: 0.8355 - categorical_accuracy: 0.9058 - val_loss: 1.8789 - val_categorical_accuracy: 0.3833
# Epoch 13/30
# 23/23 [==============================] - 36s 2s/step - loss: 0.8372 - categorical_accuracy: 0.9014 - val_loss: 1.7752 - val_categorical_accuracy: 0.4667
# Epoch 14/30
#
# Epoch 00014: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00014-0.80222-0.90000.h5
# 23/23 [==============================] - 38s 2s/step - loss: 0.8040 - categorical_accuracy: 0.9101 - val_loss: 1.6557 - val_categorical_accuracy: 0.5167
# Epoch 15/30
#  7/23 [========>.....................] - ETA: 18s - loss: 0.8710 - categorical_accuracy: 0.8952
# Epoch 00015: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00015-0.85906-0.90417.h5
# 23/23 [==============================] - 36s 2s/step - loss: 0.8372 - categorical_accuracy: 0.9043 - val_loss: 1.5261 - val_categorical_accuracy: 0.5750
# Epoch 16/30
# 14/23 [=================>............] - ETA: 11s - loss: 0.8215 - categorical_accuracy: 0.8952
# Epoch 00016: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00016-0.82260-0.89778.h5
# 23/23 [==============================] - 36s 2s/step - loss: 0.8349 - categorical_accuracy: 0.8928 - val_loss: 1.5746 - val_categorical_accuracy: 0.5833
# Epoch 17/30
# 21/23 [==========================>...] - ETA: 2s - loss: 0.7952 - categorical_accuracy: 0.9190
# Epoch 00017: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00017-0.79158-0.92121.h5
# 23/23 [==============================] - 36s 2s/step - loss: 0.7880 - categorical_accuracy: 0.9232 - val_loss: 1.4238 - val_categorical_accuracy: 0.6583
# Epoch 18/30
# 23/23 [==============================] - 36s 2s/step - loss: 0.8213 - categorical_accuracy: 0.9000 - val_loss: 1.4454 - val_categorical_accuracy: 0.6000
# Epoch 19/30
#  5/23 [=====>........................] - ETA: 21s - loss: 0.8045 - categorical_accuracy: 0.9000
# Epoch 00019: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00019-0.79228-0.91111.h5
# 23/23 [==============================] - ETA: 0s - loss: 0.8241 - categorical_accuracy: 0.8986
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 23/23 [==============================] - 37s 2s/step - loss: 0.8241 - categorical_accuracy: 0.8986 - val_loss: 1.5157 - val_categorical_accuracy: 0.6167
# Epoch 20/30
# 12/23 [==============>...............] - ETA: 13s - loss: 0.8093 - categorical_accuracy: 0.8972
# Epoch 00020: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00020-0.81284-0.89487.h5
# 23/23 [==============================] - 38s 2s/step - loss: 0.8136 - categorical_accuracy: 0.8986 - val_loss: 1.3246 - val_categorical_accuracy: 0.6917
# Epoch 21/30
# 19/23 [=======================>......] - ETA: 4s - loss: 0.8386 - categorical_accuracy: 0.9070
# Epoch 00021: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00021-0.83548-0.90833.h5
# 23/23 [==============================] - 35s 2s/step - loss: 0.8268 - categorical_accuracy: 0.9130 - val_loss: 1.3541 - val_categorical_accuracy: 0.6833
# Epoch 22/30
# 23/23 [==============================] - 37s 2s/step - loss: 0.8283 - categorical_accuracy: 0.9174 - val_loss: 1.2745 - val_categorical_accuracy: 0.7083
# Epoch 23/30
#  3/23 [==>...........................] - ETA: 17s - loss: 0.8628 - categorical_accuracy: 0.8556
# Epoch 00023: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00023-0.88356-0.85000.h5
# 23/23 [==============================] - 37s 2s/step - loss: 0.8260 - categorical_accuracy: 0.9029 - val_loss: 1.2566 - val_categorical_accuracy: 0.7667
# Epoch 24/30
# 10/23 [============>.................] - ETA: 14s - loss: 0.7872 - categorical_accuracy: 0.9300
# Epoch 00024: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00024-0.80404-0.92424.h5
# 23/23 [==============================] - 35s 2s/step - loss: 0.8326 - categorical_accuracy: 0.9029 - val_loss: 1.2564 - val_categorical_accuracy: 0.7833
# Epoch 25/30
# 17/23 [=====================>........] - ETA: 8s - loss: 0.7997 - categorical_accuracy: 0.9235
# Epoch 00025: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00025-0.79544-0.92593.h5
# 23/23 [==============================] - 37s 2s/step - loss: 0.8046 - categorical_accuracy: 0.9203 - val_loss: 1.2062 - val_categorical_accuracy: 0.7750
# Epoch 26/30
# 23/23 [==============================] - 36s 2s/step - loss: 0.8408 - categorical_accuracy: 0.8928 - val_loss: 1.2126 - val_categorical_accuracy: 0.7917
# Epoch 27/30
#  1/23 [>.............................] - ETA: 0s - loss: 0.7564 - categorical_accuracy: 0.9000
# Epoch 00027: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00027-0.83319-0.86667.h5
# 23/23 [==============================] - 37s 2s/step - loss: 0.7972 - categorical_accuracy: 0.9072 - val_loss: 1.1373 - val_categorical_accuracy: 0.8333
# Epoch 28/30
#  8/23 [=========>....................] - ETA: 17s - loss: 0.8680 - categorical_accuracy: 0.8625
# Epoch 00028: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00028-0.85423-0.87407.h5
# 23/23 [==============================] - 37s 2s/step - loss: 0.8496 - categorical_accuracy: 0.8812 - val_loss: 1.1670 - val_categorical_accuracy: 0.7917
# Epoch 29/30
# 15/23 [==================>...........] - ETA: 9s - loss: 0.8161 - categorical_accuracy: 0.9156
# Epoch 00029: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00029-0.82260-0.91250.h5
# 23/23 [==============================] - 35s 2s/step - loss: 0.8154 - categorical_accuracy: 0.9116 - val_loss: 0.9962 - val_categorical_accuracy: 0.8667
# Epoch 30/30
# 22/23 [===========================>..] - ETA: 1s - loss: 0.8157 - categorical_accuracy: 0.9091
# Epoch 00030: saving model to model_init_2021-06-2717_41_13.168834/model_3d-00030-0.81626-0.90725.h5
# 23/23 [==============================] - 36s 2s/step - loss: 0.8163 - categorical_accuracy: 0.9072 - val_loss: 1.1279 - val_categorical_accuracy: 0.8000

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=False)
f.set_figheight(5)
f.set_figwidth(15)

ax1.plot(conv3d_model_history.history['val_categorical_accuracy'])
ax1.plot(conv3d_model_history.history['categorical_accuracy'])
ax1.title.set_text('model accuracy')
ax1.set_ylabel('accuracy')
ax1.set_xlabel('epoch')
ax1.legend(['train', 'test'], loc='upper left')

ax2.plot(conv3d_model_history.history['val_loss'])
ax2.plot(conv3d_model_history.history['loss'])
ax2.title.set_text('Loss function')
ax2.set_ylabel('Loss')
ax2.set_xlabel('epoch')
ax2.legend(['train', 'test'], loc='upper left')
plt.show()
